# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/tushspeed/tushspeed.github.io/blob/master/sample_notifications_flow.ipynb)

# %% [markdown]
# # Notebook Flow

# %% [markdown]
# 1. Import the relevant libraris (pandas, numpy, firebase api, bigquery, mysql)

# %% [markdown]
# 2. Campaign definition - activation, reactivation, engagement (incet, non incent)

# %% [markdown]
# 3. Audience definition (query going back to BQ <> defult filters to be defined)

# %% [markdown]
# 4. Scrub the list against checks (frequency cap, sleep time, priority)

# %% [markdown]
# 5. Message payload setting (push, inapp, inbox)

# %% [markdown]
# 6. Call Firebase API for launch (retry, sleep methods)
